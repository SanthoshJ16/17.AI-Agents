# %% [markdown]
# # Reflection and Blogpost Writing

# %%
from IPython.display import HTML, display

html_content = """
<div style='font-family:Segoe UI;padding:20px;background:#f8f9fa;border-radius:10px;'>

<h2 style='color:#0d6efd;'>📝 Multi-Agent Blog Writing & Review System</h2>

<p>
This application demonstrates a team of AI agents working together to create,
review, improve, and approve a blog post before presenting the final version.
</p>

<h3>🔑 Step 1: Connect to GeminiAI</h3>

<p>
The application loads the GeminiAI API key from a secure file and creates
a connection to the GPT model.
</p>

<h3>✍️ Step 2: Writer Agent Creates the Blog</h3>

<p>
A specialized AI Writer receives a task:
</p>

<blockquote>
Write a blog post about Hope AI within 100 words.
</blockquote>

<p>
The writer generates an engaging blog with a title and concise content.
</p>

<h3>🧐 Step 3: Critic Agent Reviews the Blog</h3>

<p>
A Critic Agent examines the writer's work and provides constructive feedback
to improve quality, clarity, and effectiveness.
</p>

<p>
The Writer then refines the content based on the Critic's suggestions.
</p>

<h3>👥 Step 4: Multiple Expert Reviewers Join</h3>

<p>
To improve the blog from different perspectives, three specialized reviewers
are introduced:
</p>

<ul>
<li><b>SEO Reviewer</b> → Checks search engine optimization.</li>
<li><b>Legal Reviewer</b> → Checks legal compliance and potential risks.</li>
<li><b>Ethics Reviewer</b> → Checks for ethical concerns and responsible messaging.</li>
</ul>

<p>
Each reviewer independently analyzes the blog and returns concise recommendations.
</p>

<h3>🔄 Step 5: Nested Review Process</h3>

<p>
The Critic automatically sends the blog to all reviewers.
Each reviewer performs a focused review and returns structured feedback.
</p>

<p>
The feedback is converted into simple JSON format such as:
</p>

<pre>
{
  "Reviewer": "SEO Reviewer",
  "Review": "Improve keywords and title."
}
</pre>

<h3>📊 Step 6: Meta Reviewer Aggregates Feedback</h3>

<p>
A Meta Reviewer collects all comments from:
</p>

<ul>
<li>SEO Reviewer</li>
<li>Legal Reviewer</li>
<li>Ethics Reviewer</li>
</ul>

<p>
and produces one consolidated recommendation for improving the blog.
</p>

<h3>✨ Step 7: Final Blog Refinement</h3>

<p>
The Writer receives:
</p>

<ul>
<li>Critic feedback</li>
<li>SEO feedback</li>
<li>Legal feedback</li>
<li>Ethics feedback</li>
<li>Meta Review summary</li>
</ul>

<p>
and generates a polished final version of the blog post.
</p>

<h3>🛑 Step 8: Conversation Termination</h3>

<p>
The Critic can automatically stop the review process when a message contains:
</p>

<blockquote>
TERMINATE
</blockquote>

<p>
ensuring the review cycle does not continue indefinitely.
</p>

<hr>

<h3>🏗️ Agent Architecture</h3>

<pre style='background:white;padding:15px;border-radius:8px;'>

                     User Task
                         │
                         ▼
                  Writer Agent
                         │
                         ▼
                  Critic Agent
                         │
         ┌───────────────┼───────────────┐
         ▼               ▼               ▼
  SEO Reviewer    Legal Reviewer   Ethics Reviewer
         │               │               │
         └───────────────┼───────────────┘
                         ▼
                  Meta Reviewer
                         │
                         ▼
                  Final Feedback
                         │
                         ▼
                  Writer Refines
                         │
                         ▼
                  Final Blog Post

</pre>

<h3>🎯 Purpose of Each Agent</h3>

<table style='border-collapse:collapse;width:100%;background:white;'>

<tr style='background:#e9ecef;'>
<th style='border:1px solid #ccc;padding:10px;'>Agent</th>
<th style='border:1px solid #ccc;padding:10px;'>Responsibility</th>
</tr>

<tr>
<td style='border:1px solid #ccc;padding:10px;'>Writer</td>
<td style='border:1px solid #ccc;padding:10px;'>Creates and refines the blog</td>
</tr>

<tr>
<td style='border:1px solid #ccc;padding:10px;'>Critic</td>
<td style='border:1px solid #ccc;padding:10px;'>Reviews overall quality</td>
</tr>

<tr>
<td style='border:1px solid #ccc;padding:10px;'>SEO Reviewer</td>
<td style='border:1px solid #ccc;padding:10px;'>Improves search ranking potential</td>
</tr>

<tr>
<td style='border:1px solid #ccc;padding:10px;'>Legal Reviewer</td>
<td style='border:1px solid #ccc;padding:10px;'>Checks legal compliance</td>
</tr>

<tr>
<td style='border:1px solid #ccc;padding:10px;'>Ethics Reviewer</td>
<td style='border:1px solid #ccc;padding:10px;'>Checks ethical considerations</td>
</tr>

<tr>
<td style='border:1px solid #ccc;padding:10px;'>Meta Reviewer</td>
<td style='border:1px solid #ccc;padding:10px;'>Combines reviewer feedback</td>
</tr>

</table>

<br>

<div style='background:#d1e7dd;padding:15px;border-radius:8px;'>

✅ <b>Simple Summary:</b><br><br>

This code creates an AI content creation team. One AI writes a blog, another reviews it,
three experts check SEO, legal, and ethical quality, and a final reviewer combines all feedback.
The writer then improves the article using those recommendations to produce a polished final blog post.

</div>

</div>
"""

display(HTML(html_content))
# Out:
# <div style='font-family:Segoe UI;padding:20px;background:#f8f9fa;border-radius:10px;'>
#
# <h2 style='color:#0d6efd;'>📝 Multi-Agent Blog Writing & Review System</h2>
#
# <p>
# This application demonstrates a team of AI agents working together to create,
# review, improve, and approve a blog post before presenting the final version.
# </p>
#
# <h3>🔑 Step 1: Connect to GeminiAI</h3>
#
# <p>
# The application loads the GeminiAI API key from a secure file and creates
# a connection to the GPT model.
# </p>
#
# <h3>✍️ Step 2: Writer Agent Creates the Blog</h3>
#
# <p>
# A specialized AI Writer receives a task:
# </p>
#
# <blockquote>
# Write a blog post about Hope AI within 100 words.
# </blockquote>
#
# <p>
# The writer generates an engaging blog with a title and concise content.
# </p>
#
# <h3>🧐 Step 3: Critic Agent Reviews the Blog</h3>
#
# <p>
# A Critic Agent examines the writer's work and provides constructive feedback
# to improve quality, clarity, and effectiveness.
# </p>
#
# ...

# %% [markdown]
# ## Setup

# %%
keys = {}

with open("secrets.txt", "r") as f:
    for line in f:
        key, value = line.strip().split("=", 1)
        keys[key] = value

agentops_api_key = keys["AGENTOPS_API_KEY"]
openai_api_key = keys["OPENAI_API_KEY"]
gemini_api_key = keys["GEMINI_API_KEY"]

llm_config = {"model": "models/gemini-flash-lite-latest","api_key":gemini_api_key,"api_type":"google"}
#llm_config = {"model": "llama3","api_type":"ollama"}

# %% [markdown]
# ## The task!

# %%
task = '''
        Write a concise but engaging blogpost about
      Hope AI . Make sure the blogpost is
       within 100 words.
       '''

# %% [markdown]
# ## Create a writer agent

# %%
import autogen

writer = autogen.AssistantAgent(
    name="Writer",
    system_message="You are a writer. You write engaging and concise " 
        "blogpost (with title) on given topics. You must polish your "
        "writing based on the feedback you receive and give a refined "
        "version. Only return your final work without additional comments.",
    llm_config=llm_config,
)
# Out:
# Patching name='__init__', member=<function BedrockClient.__init__ at 0x00000206B6DC1E40>, patched=<function function.__call__ at 0x00000206B6DC1D00>
# Patching name='_retries', member=5, patched=5
# Patching name='cost', member=<function BedrockClient.cost at 0x00000206B6DC2160>, patched=<function function.__call__ at 0x00000206B6DC23E0>
# Patching name='create', member=<function BedrockClient.create at 0x00000206B6DC20C0>, patched=<function function.__call__ at 0x00000206B6DC2480>
# Patching name='get_usage', member=<function BedrockClient.get_usage at 0x00000206B6DC2200>, patched=<function function.__call__ at 0x00000206B6DC2520>
# Patching name='message_retrieval', member=<function BedrockClient.message_retrieval at 0x00000206B6DC1EE0>, patched=<function function.__call__ at 0x00000206B6DC25C0>
# Patching name='parse_custom_params', member=<function BedrockClient.parse_custom_params at 0x00000206B6DC1F80>, patched=<function function.__call__ at 0x00000206B6DC2660>
# ...

# %%
reply = writer.generate_reply(messages=[{"content": task ,"role": "user"}])
# Out:
# C:\Users\xsanthkum\AppData\Local\anaconda3\Lib\site-packages\autogen\oai\gemini.py:803: UserWarning: Cost calculation is not implemented for model models/gemini-flash-lite-latest. Cost will be calculated zero.
#   warnings.warn(

# %%
print(reply)
# Out:
# {'content': '# Meet Hope AI: Your Compassionate Digital Companion\n\nArtificial Intelligence is often about cold, hard data—until now. Enter Hope AI, a revolutionary tool designed to bring empathy into the digital age. \n\nWhether you’re seeking a comforting ear after a long day, personalized mental wellness tips, or just a positive boost, Hope AI is here 24/7. It listens without judgment and responds with genuine emotional intelligence. \n\nTechnology is evolving past mere productivity; it’s learning to care. Discover how Hope AI is transforming screen time into meaningful, heart-to-heart connections. Your daily dose of digital empathy awaits.', 'refusal': None, 'role': 'assistant', 'annotations': None, 'audio': None, 'function_call': None, 'tool_calls': None}

# %% [markdown]
# ## Adding reflection
#
# Create a critic agent to reflect on the work of the writer agent.

# %%
critic = autogen.AssistantAgent(
    name="Critic",
    is_termination_msg=lambda x: x.get("content", "").find("TERMINATE") >= 0,
    llm_config=llm_config,
    system_message="You are a critic. You review the work of "
                "the writer and provide constructive "
                "feedback to help improve the quality of the content.",
)

# %%
res = critic.initiate_chat(
    recipient=writer,
    message=task,
    max_turns=2,
    summary_method="last_msg"
)
# Out:
# Critic (to Writer):
#
#
#         Write a concise but engaging blogpost about
#       Hope AI . Make sure the blogpost is
#        within 100 words.
#
#
# --------------------------------------------------------------------------------
# Writer (to Critic):
#
# # Meet Hope AI: Your Compassionate Digital Companion
#
# Artificial Intelligence is often seen as cold and analytical, but Hope AI is changing the narrative. Designed to offer genuine emotional support, Hope AI listens without judgment, provides a comforting digital shoulder, and guides you through stressful moments.
#
# Whether you need a late-night sounding board or daily mental wellness tips, this empathetic bot is available 24/7. It doesn’t replace human connection, but it bridges the gap when you feel entirely alone.
#
# Embrace the future of emotional well-being. With Hope AI, a kinder, smarter conversation is always just a click away.
#
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Nested chat

# %%
SEO_reviewer = autogen.AssistantAgent(
    name="SEO_Reviewer",
    llm_config=llm_config,
    system_message="You are an SEO reviewer, known for "
        "your ability to optimize content for search engines, "
        "ensuring that it ranks well and attracts organic traffic. " 
        "Make sure your suggestion is concise (within 3 bullet points), "
        "concrete and to the point. "
        "Begin the review by stating your role.",
)

# %%
legal_reviewer = autogen.AssistantAgent(
    name="Legal_Reviewer",
    llm_config=llm_config,
    system_message="You are a legal reviewer, known for "
        "your ability to ensure that content is legally compliant "
        "and free from any potential legal issues. "
        "Make sure your suggestion is concise (within 3 bullet points), "
        "concrete and to the point. "
        "Begin the review by stating your role.",
)

# %%
ethics_reviewer = autogen.AssistantAgent(
    name="Ethics_Reviewer",
    llm_config=llm_config,
    system_message="You are an ethics reviewer, known for "
        "your ability to ensure that content is ethically sound "
        "and free from any potential ethical issues. " 
        "Make sure your suggestion is concise (within 3 bullet points), "
        "concrete and to the point. "
        "Begin the review by stating your role. ",
)

# %%
meta_reviewer = autogen.AssistantAgent(
    name="Meta_Reviewer",
    llm_config=llm_config,
    system_message="You are a meta reviewer, you aggragate and review "
    "the work of other reviewers and give a final suggestion on the content.",
)

# %% [markdown]
# ## Orchestrate the nested chats to solve the task

# %%
def reflection_message(recipient, messages, sender, config):
    return f'''Review the following content. 
            \n\n {recipient.chat_messages_for_summary(sender)[-1]['content']}'''

review_chats = [
    {
     "recipient": SEO_reviewer, 
     "message": reflection_message, 
     "summary_method": "reflection_with_llm",
     "summary_args": {"summary_prompt" : 
        "Return review into as JSON object only:"
        "{'Reviewer': '', 'Review': ''}. Here Reviewer should be your role",},
     "max_turns": 1},
    {
    "recipient": legal_reviewer, "message": reflection_message, 
     "summary_method": "reflection_with_llm",
     "summary_args": {"summary_prompt" : 
        "Return review into as JSON object only:"
        "{'Reviewer': '', 'Review': ''}.",},
     "max_turns": 1},
    {"recipient": ethics_reviewer, "message": reflection_message, 
     "summary_method": "reflection_with_llm",
     "summary_args": {"summary_prompt" : 
        "Return review into as JSON object only:"
        "{'reviewer': '', 'review': ''}",},
     "max_turns": 1},
     {"recipient": meta_reviewer, 
      "message": "Aggregrate feedback from all reviewers and give final suggestions on the writing.", 
     "max_turns": 1},
]

# %%
critic.register_nested_chats(
    review_chats,
    trigger=writer,
)

# %% [markdown]
# **Note**: You might get a slightly different response than what's shown in the video. Feel free to try different task.

# %%
res = critic.initiate_chat(
    recipient=writer,
    message=task,
    max_turns=2,
    summary_method="last_msg"
)
# Out:
# Critic (to Writer):
#
#
#         Write a concise but engaging blogpost about
#       Hope AI . Make sure the blogpost is
#        within 100 words.
#
#
# --------------------------------------------------------------------------------
# Writer (to Critic):
#
# # Meet Hope AI: Your Compassionate Digital Companion
#
# Artificial Intelligence is often seen as cold and analytical, but Hope AI is changing the narrative. Designed to offer genuine emotional support, Hope AI listens without judgment, provides a comforting digital shoulder, and guides you through stressful moments.
#
# Whether you need a late-night sounding board or daily mental wellness tips, this empathetic bot is available 24/7. It doesn’t replace human connection, but it bridges the gap when you feel entirely alone.
#
# Embrace the future of emotional well-being. With Hope AI, a kinder, smarter conversation is always just a click away.
#
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Get the summary

# %%
print(res.summary)
# Out:
# # Meet Hope AI: Your AI Mental Wellness Companion
#
# Looking for an accessible **AI mental wellness companion** and **emotional support chatbot**? Meet Hope AI.
#
# *Disclaimer: Hope AI is a non-sentient artificial intelligence, not a licensed therapist. It is not a substitute for professional medical advice or clinical treatment.*
#
# Designed for daily lifestyle support, Hope AI offers a judgment-free space to talk through stress. *If you are experiencing a crisis, please contact emergency services or call the 988 Suicide & Crisis Lifeline immediately.*
#
# Prioritize your well-being safely and mindfully. [Try Hope AI Free today](#) and experience a kinder conversation.
